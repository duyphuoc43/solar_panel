# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install ultralytics

# %%
# import subprocess

# # Đường dẫn đến thư mục mà bạn muốn lưu repository GitHub
# folder_path = "data"

# # URL của repository GitHub
# github_repo_url = "https://github.com/duyphuoc43/solar_panel.git"

# # Sử dụng git để clone repository vào thư mục được chỉ định
# subprocess.run(["git", "clone", github_repo_url, folder_path])

# %%
import wandb

wandb.init(mode='offline')
# Out:
# Finishing last run (ID:snr2dnxd) before initializing another...
# You can sync this run to the cloud by running:<br/><code>wandb sync c:\Users\duyph\Desktop\solar_panel\wandb\offline-run-20240825_145705-snr2dnxd<code>
# Find logs at: <code>.\wandb\offline-run-20240825_145705-snr2dnxd\logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# Successfully finished last run (ID:snr2dnxd). Initializing new run:<br/>
# Tracking run with wandb version 0.17.7
# W&B syncing is set to <code>`offline`<code> in this directory.  <br/>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
from ultralytics import YOLO

# Load a model

# model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# model = YOLO('yolov9e.yaml').load('best_9e.pt')  # build from YAML and transfer weights
model = YOLO('yolov9e.pt')  # build a new model from YAML
# Train the model

# %%
results = model.train(data="/kaggle/working/data/faultme/data.yaml", epochs=300,batch = 2,
                      imgsz=800,flipud=0.5, fliplr=0.5 , bgr=0.5, copy_paste=0.5, 
                      nbs=6, erasing=0.4, crop_fraction=1.0,
                      augment=True,multi_scale=True, box=10, show=False, 
                      save_frames=False, save_txt=False, save_conf=False, save_crop=False, 
                      show_labels=True, show_conf=True, show_boxes=True, line_width=None,dnn=True
                      )
# model.train(data='data.yaml',
#                 augment = True,
#                 epochs=200,
#                 batch = 2,
#                 imgsz=1000, 
#                 multi_scale=True,
#                 crop_fraction=0.8,
#                 nbs=6, erasing=0.4,
#                 hsv_h = 0.015, # image HSV-Hue augmentation (fraction)
#                 hsv_s = 0.015, # image HSV-Saturation augmentation (fraction)
#                 hsv_v = 0.015, # image HSV-Value augmentation (fraction)
#                 degrees = 1,
#                 translate= 0.1,
#                 scale = 0.5,
#                 shear = 0.5,
#                 perspective = 0,
#                 flipud = 0.5,
#                 fliplr = 0.5,
#                 mosaic = 0.5,
#                 mixup = 0,
#                 copy_paste = 1,
#                 dnn=True,
#                 show_boxes=True,
#                 val = True)
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %%
import os
import numpy as np
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")  # build a new model from scratch
from ultralytics import YOLO

# Load a model
# model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model
image_path = '/kaggle/working/data/vietHuong/Screenshot 2024-05-07 215310.png'
# Run batched inference on a list of images
results = model([image_path])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    result.show()  # display to screen
    result.save(filename='/kaggle/working/result.jpg')  # save to disk
import matplotlib.pyplot as plt

# Đọc ảnh từ đường dẫn
image = plt.imread("/kaggle/working/result.jpg")

# Hiển thị ảnh
plt.imshow(image)
plt.axis('off')  # Tắt hiển thị trục
plt.show()

# %%
# Đoạn mã bạn cung cấp là một lời gọi hàm train để huấn luyện một mô hình học máy, với các tham số cấu hình được cung cấp để điều chỉnh quá trình huấn luyện. Dưới đây là giải thích chi tiết cho từng tham số trong hàm này:

# model.train(data='src/models/aerial_objects.yaml', ...): Hàm train được gọi để huấn luyện mô hình, với tệp dữ liệu được xác định bởi aerial_objects.yaml.

# augment = True: Bật tính năng tăng cường dữ liệu (data augmentation) để cải thiện khả năng tổng quát hóa của mô hình.

# epochs = v8_hyperparameters["epochs"]: Số lượng epochs, tức là số lần toàn bộ tập dữ liệu huấn luyện được chạy qua mô hình.

# imgsz = v8_hyperparameters["imgsz"]: Kích thước của các hình ảnh đầu vào.

# batch = v8_hyperparameters["batch"]: Kích thước batch, tức là số lượng mẫu được xử lý cùng lúc trong một lần cập nhật.

# device = v8_hyperparameters["device"]: Thiết bị để huấn luyện mô hình, ví dụ như CPU hoặc GPU.

# patience = v8_hyperparameters["batch"]: Số epochs chờ đợi mà không có cải thiện để dừng sớm (early stopping).

# lr0 = v8_hyperparameters["lr0"]: Tốc độ học ban đầu.

# name = experiment_name: Tên của thí nghiệm hoặc phiên huấn luyện.

# optimizer = v8_hyperparameters["optimizer"]: Loại bộ tối ưu hóa sử dụng, có thể là Adam, Adamax, AdamW, NAdam, RAdam, RMSProp, hoặc tự động chọn (auto).

# weight_decay = v8_hyperparameters["weight_decay"]: Hệ số suy giảm trọng số, giúp ngăn chặn overfitting.

# hsv_h = 0.015: Tham số tăng cường màu sắc Hue (sắc độ) trong không gian màu HSV.

# hsv_s = 0.7: Tham số tăng cường màu sắc Saturation (độ bão hòa) trong không gian màu HSV.

# hsv_v = 0.4: Tham số tăng cường màu sắc Value (giá trị độ sáng) trong không gian màu HSV.

# degrees = 0: Tham số xoay góc của hình ảnh trong quá trình tăng cường.

# translate= 0.1: Tham số dịch chuyển hình ảnh theo tỷ lệ.

# scale = 0: Tham số thay đổi kích thước hình ảnh theo tỷ lệ.

# shear = 0: Tham số cắt (shear) hình ảnh theo tỷ lệ.

# perspective = 0: Tham số biến đổi phối cảnh của hình ảnh.

# flipud = 0.5: Xác suất lật hình ảnh theo chiều dọc.

# fliplr = 0.5: Xác suất lật hình ảnh theo chiều ngang.

# mosaic = 1.0: Sử dụng kỹ thuật mosaic để ghép nhiều hình ảnh vào một.

# mixup = 0: Tỉ lệ sử dụng kỹ thuật mixup để trộn lẫn các hình ảnh và nhãn.

# copy_paste = 0: Tỉ lệ sử dụng kỹ thuật copy-paste để tăng cường dữ liệu.

# auto_augmnet = "randaugment": Tự động tăng cường dữ liệu sử dụng phương pháp RandAugment.

# val = True: Thực hiện đánh giá (validation) trên tập dữ liệu kiểm tra trong quá trình huấn luyện.

# Đây là một tập hợp các tham số phong phú để cấu hình quá trình huấn luyện mô hình học máy, nhằm tối ưu hóa hiệu suất và cải thiện độ chính xác của mô hình trên dữ liệu mới.
